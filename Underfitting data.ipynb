# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv(r"E:\internship\underfitting_dataset.csv")
df
# Out:
#     Study_Hours  Marks
# 0             1      1
# 1             1      3
# 2             1      2
# 3             2      1
# 4             2      4
# 5             2      3
# 6             3      2
# 7             3      5
# 8             3      4
# 9             4      2
# 10            4      6
# 11            4      5
# 12            5      3
# 13            5      7
# 14            5      6
# 15            6      4
# 16            6      8
# 17            6      7
# 18            7      5
# 19            7      9
# 20            7      8
# 21            8      6
# 22            8     10
# 23            8      9
# 24            9      7
# 25            9     11
# 26            9     10
# 27           10      8
# 28           10     12
# 29           10     11

# %%
X = df[["Study_Hours"]]
Y = df["Marks"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4)
X_train
# Out:
#     Study_Hours
# 24            9
# 5             2
# 20            7
# 15            6
# 13            5
# 16            6
# 29           10
# 22            8
# 21            8
# 27           10
# 23            8
# 3             2
# 14            5
# 9             4
# 11            4
# 1             1
# 2             1
# 7             3

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

# %%
Y_train_pred
# Out:
# array([8.72868217, 2.9379845 , 7.07419712, 6.2469546 , 5.41971207,
#        6.2469546 , 9.5559247 , 7.90143965, 7.90143965, 9.5559247 ,
#        7.90143965, 2.9379845 , 5.41971207, 4.59246955, 4.59246955,
#        2.11074197, 2.11074197, 3.76522702])

# %%
train_mse = mean_squared_error(Y_train, Y_train_pred)
test_mse = mean_squared_error(Y_test, Y_test_pred)

# %%
print("Training MSE:", train_mse)
print("Testing MSE:", test_mse)
# Out:
# Training MSE: 2.306016980435585
# Testing MSE: 2.891303627995274

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X, model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Linear Regression Model")
plt.show()

# %%
residuals = Y_test - Y_test_pred
residuals
# Out:
# 8     0.234773
# 18   -2.074197
# 10    1.407530
# 28    2.444075
# 17    0.753045
# 12   -2.419712
# 19    1.925803
# 4     1.062016
# 25    2.271318
# 26    1.271318
# 6    -1.765227
# 0    -1.110742
# Name: Marks, dtype: float64

# %%
plt.figure()
plt.scatter(X_test,residuals)
plt.axhline(0)
plt.xlabel("Study Hours (Test)")
plt.ylabel("Residuals")
plt.title("Residuals Plot (Test Data)")
plt.show()
