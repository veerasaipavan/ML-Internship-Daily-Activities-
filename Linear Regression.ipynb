# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({
    "study_hours":[1,2,3,4,5],
    "marks":[2,4,5,4,5]
})
df
# Out:
#    study_hours  marks
# 0            1      2
# 1            2      4
# 2            3      5
# 3            4      4
# 4            5      5

# %%
X=df[["study_hours"]]
Y=df[["marks"]]

# %%
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
X_line = pd.DataFrame(
    {'study_hours': np.linspace(X.min()[0], X.max()[0], 100)}
)
Y_line = model.predict(X_line)
X_line
# Out:
# C:\Users\KEDARI\AppData\Local\Temp\ipykernel_2892\1962213491.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   {'study_hours': np.linspace(X.min()[0], X.max()[0], 100)}
#     study_hours
# 0      1.000000
# 1      1.040404
# 2      1.080808
# 3      1.121212
# 4      1.161616
# ..          ...
# 95     4.838384
# 96     4.878788
# 97     4.919192
# 98     4.959596
# 99     5.000000
#
# [100 rows x 1 columns]

# %%
print("Slope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)
# Out:
# Slope (m): [0.6]
# Intercept (b): [2.2]

# %%
X_new=pd.DataFrame({'study_hours':[4.0]})
Y_new=model.predict(X_new)
print("Predict Value: ",Y_new)
# Out:
# Predict Value:  [[4.6]]

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X_line, Y_line)
plt.scatter(X_new,Y_new)
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Linear Regression: Best-Fit Line")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

Y_pred = model.predict(X)
mse = mean_squared_error(Y, Y_pred)

print("MSE:", mse)
# Out:
# MSE: 0.4799999999999998

# %% [markdown]
# ### Multiple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv(r"C:\Users\KEDARI\AppData\Local\Packages\5319275A.51895FA4EA97F_cv1g1gvanyjgm\LocalState\sessions\0D708E655A9FD54835A33596C71AA78888185876\transfers\2026-01\MLR_Study_marks.csv")
df
# Out:
#     Study_Hours  Attendance  Sleep_Hours  Marks
# 0             2          60            5     48
# 1             3          62            5     50
# 2             4          65            6     55
# 3             5          68            6     58
# 4             6          70            6     60
# ..          ...         ...          ...    ...
# 72            6          79            6     68
# 73            7          82            7     71
# 74            8          85            7     75
# 75            9          88            7     78
# 76           10          96            8     84
#
# [77 rows x 4 columns]

# %%
X = df[["Study_Hours", "Attendance", "Sleep_Hours"]]
Y = df["Marks"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state = 40)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)

print("\nModel Intercept:", model.intercept_)
print("Model Coefficients:", model.coef_)
# Out:
# Model Intercept: -0.6066101740192664
# Model Coefficients: [0.9420473  0.74064362 0.57973332]

# %%
Y_pred = model.predict(X_test)

# %%
plt.scatter(Y_test, Y_pred)
plt.xlabel("Actual Marks")
plt.ylabel("Predicted Marks")
plt.title("Actual vs Predicted Marks")
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--')
plt.show()

# %%
Y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print("\nMean Sqaured Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Sqaured Error: 0.6339347099085438
# R^2 Score: 0.9919846255871692
